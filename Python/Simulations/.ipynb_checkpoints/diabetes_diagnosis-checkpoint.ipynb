# %%
import sys
sys.path.append("/Users/heeyeon/Desktop/EM-PGM_python/")

import Data.diabetes_diagnosis_data as dat
import importlib
importlib.reload(dat)
# Out:
# <module 'Data.diabetes_diagnosis_data' from '/Users/heeyeon/Desktop/EM-PGM_python/Data/diabetes_diagnosis_data.py'>

# %%
import numpy as np
import pickle

log_lambdas = np.linspace(np.log10(10**-4), np.log10(1), 30)
lambda_s = 10 ** log_lambdas

# %%
## mvFMR-MCP with the EM-PGM algorithm ##

import sys
sys.path.append("/Users/heeyeon/Desktop/EM-PGM_python/")

import Scripts.Analysis.PGM_mvFMR_MCP as pgm
import importlib
importlib.reload(pgm)
# Out:
# <module 'Scripts.Analysis.PGM_mvFMR_MCP' from '/Users/heeyeon/Desktop/EM-PGM_python/Scripts/Analysis/PGM_mvFMR_MCP.py'>

# %%
PGM_diabetes_diagnosis = pgm.PGM_mvFMR_MCP_nonfixedK(dat.X, dat.Y, eta_val=0.25, a=3.7, lambdas=lambda_s)

# %%
with open("/Users/heeyeon/Desktop/EM-PGM_python/Results/Section6.1/PGM_diabetes_diagnosis.pkl", "wb") as f:
    pickle.dump(PGM_diabetes_diagnosis, f)

# %%
## 불러올 때 ##
# with open("/Users/heeyeon/Desktop/EM-PGM_python/Results/Section6.1/PGM_diabetes_diagnosis.pkl", "rb") as f:
#     result = pickle.load(f)

# %%
## mvFMR-MCP with the EM-ADMM algorithm ##

import sys
sys.path.append("/Users/heeyeon/Desktop/EM-PGM_python/")

import Scripts.Analysis.ADMM_mvFMR_MCP as admm
import importlib
importlib.reload(admm)
# Out:
# <module 'Scripts.Analysis.ADMM_mvFMR_MCP' from '/Users/heeyeon/Desktop/EM-PGM_python/Scripts/Analysis/ADMM_mvFMR_MCP.py'>

# %%
ADMM_diabetes_diagnosis = admm.ADMM_mvFMR_MCP_nonfixedK(dat.X, dat.Y, rho=1, alpha=1.5, a=3.7, lambdas=lambda_s)

# %%
with open("/Users/heeyeon/Desktop/EM-PGM_python/Results/Section6.1/ADMM_diabetes_diagnosis.pkl", "wb") as f:
    pickle.dump(ADMM_diabetes_diagnosis, f)

# %%
## 불러올 때 ##
# with open("/Users/heeyeon/Desktop/EM-PGM_python/Results/Section6.1/ADMM_diabetes_diagnosis.pkl", "rb") as f:
#     result = pickle.load(f)

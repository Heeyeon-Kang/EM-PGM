# %%
import sys
sys.path.append("/Users/heeyeon/Desktop/EM-PGM_python/")

import Data.CCLE_data as dat
import importlib
importlib.reload(dat)
# Out:
# <module 'Data.CCLE_data' from '/Users/heeyeon/Desktop/EM-PGM_python/Data/CCLE_data.py'>

# %%
import numpy as np
import pickle

log_lambdas = np.linspace(np.log10(10**-2), np.log10(1), 30)
lambda_s = 10 ** log_lambdas

# %%
## mvFMR-MCP with the EM-PGM algorithm ##

import sys
sys.path.append("/Users/heeyeon/Desktop/EM-PGM_python/")

import Scripts.Analysis.PGM_mvFMR_MCP as pgm
import importlib
importlib.reload(pgm)
# Out:
# <module 'Scripts.Analysis.PGM_mvFMR_MCP' from '/Users/heeyeon/Desktop/EM-PGM_python/Scripts/Analysis/PGM_mvFMR_MCP.py'>

# %%
PGM_CCLE = pgm.PGM_mvFMR_MCP_nonfixedK(dat.X, dat.Y, eta_val=0.01, a=3.7, lambdas=lambda_s)

# %%
with open("/Users/heeyeon/Desktop/EM-PGM_python/Results/Section6.2/PGM_CCLE.pkl", "wb") as f:
    pickle.dump(PGM_CCLE, f)

# %%
## 불러올 때 ##
# with open("/Users/heeyeon/Desktop/EM-PGM_python/Results/Section6.2/PGM_CCLE.pkl", "rb") as f:
#     PGM_CCLE = pickle.load(f)

# %%
## mvFMR-MCP with the EM-ADMM algorithm ##

import sys
sys.path.append("/Users/heeyeon/Desktop/EM-PGM_python/")

import Scripts.Analysis.ADMM_mvFMR_MCP as admm
import importlib
importlib.reload(admm)

# %%
ADMM_CCLE = admm.ADMM_mvFMR_MCP_nonfixedK(dat.X, dat.Y, rho=0.5, alpha=1.5, a=3.7, lambdas=lambda_s)

# %%
with open("/Users/heeyeon/Desktop/EM-PGM_python/Results/Section6.2/ADMM_CCLE.pkl", "wb") as f:
    pickle.dump(ADMM_CCLE, f)

# %%
## 불러올 때 ##
# with open("/Users/heeyeon/Desktop/EM-PGM_python/Results/Section6.2/ADMM_CCLE.pkl", "rb") as f:
#     ADMM_CCLE = pickle.load(f)
